# %%
class Solution:    
    def printNos(self,n):
        if n==0:
            return
        self.printNos(n-1)
        print(n,end=" ")
obj=Solution()
obj.printNos(5)
# Out:
# 1 2 3 4 5

# %%
def func(n):
    if n==0:
        return
    func(n-1)
    print(n,end=" ")
func(5)
# Out:
# 1 2 3 4 5
